# %% [markdown]
# <a href="https://colab.research.google.com/github/sayakpaul/Adversarial-Examples-in-Deep-Learning/blob/master/Adversarial_Examples_EfficientNet_AdvProp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Initial setup

# %%
# TensorFlow version
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
# Which GPU?
# !nvidia-smi
# Out:
# Tue Oct  6 05:17:09 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Other imports
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import *
from tensorflow.keras.models import *

import tensorflow_datasets as tfds
tfds.disable_progress_bar()

import matplotlib.pyplot as plt
import numpy as np
import random
import shutil
import time
import cv2
import os

# Fix the seeds
SEED = 666
tf.random.set_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Data collection

# %%
# Gather Flowers dataset
train_ds, validation_ds = tfds.load(
    "tf_flowers",
    split=["train[:85%]", "train[85%:]"],
    as_supervised=True
)

# Specify the class labels, we would need this to create targeted attacks
CLASSES = ["daisy", "dandelion", "roses", "sunflowers", "tulips"]
# Out:
# WARNING:absl:Dataset tf_flowers is hosted on GCS. It will automatically be downloaded to your
# local data directory. If you'd instead prefer to read directly from our public
# GCS bucket (recommended if you're running on GCP), you can instead set
# data_dir=gs://tfds-data/datasets.
# Downloading and preparing dataset tf_flowers/3.0.0 (download: 218.21 MiB, generated: Unknown size, total: 218.21 MiB) to /root/tensorflow_datasets/tf_flowers/3.0.0...
# Dataset tf_flowers downloaded and prepared to /root/tensorflow_datasets/tf_flowers/3.0.0. Subsequent calls will reuse this data.

# %%
# Visualization
plt.figure(figsize=(10, 10))
for i, (image, label) in enumerate(train_ds.take(9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image)
    plt.title(CLASSES[int(label)])
    plt.axis("off")

# %% [markdown]
# ## Data preparation

# %%
# Image preprocessing utils

SIZE = (224, 224)

def preprocess_image(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, SIZE)
    return (image, label)

# %%
# Construct TensorFlow dataset
BATCH_SIZE = 64
AUTO = tf.data.experimental.AUTOTUNE

train_ds = (
    train_ds
    .map(preprocess_image, num_parallel_calls=AUTO)
    .cache()
    .shuffle(1024)
    .batch(BATCH_SIZE)
    .prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
)

validation_ds = (
    validation_ds
    .map(preprocess_image, num_parallel_calls=AUTO)
    .cache()
    .batch(BATCH_SIZE)
    .prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
)

# %% [markdown]
# ## Model utilities

# %%
# Reference: https://keras.io/examples/vision/image_classification_efficientnet_fine_tuning/
def get_training_model(base_model):
    inputs = Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = Dropout(top_dropout_rate)(x)
    x = Dense(5, activation="softmax")(x)
    classifier = Model(inputs=inputs, outputs=x)
    
    return classifier

def plot_progress(hist):
    plt.plot(hist.history["loss"], label="train_loss")
    plt.plot(hist.history["val_loss"], label="validation_loss")
    plt.plot(hist.history["accuracy"], label="training_accuracy")
    plt.plot(hist.history["val_accuracy"], label="validation_accuracy")
    plt.title("Training Progress")
    plt.ylabel("accuracy/loss")
    plt.xlabel("epoch")
    plt.legend(loc="upper left")
    plt.show()

# %% [markdown]
# Fetch the [AdvProp](https://arxiv.org/abs/1911.09665) training checkpoints for EfficientNetB0 and convert the checkpoints to `.h5`.

# %%
# !wget -q https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet/advprop/efficientnet-b0.tar.gz
# !tar -xf efficientnet-b0.tar.gz

# %%
# !wget -q https://raw.githubusercontent.com/yixingfu/tensorflow/updateweights/tensorflow/python/keras/applications/efficientnet_weight_update_util.py
# !python efficientnet_weight_update_util.py --model b0 --notop --ckpt \
       efficientnet-b0/model.ckpt --o efficientnetb0_notop.h5
# Out:
# 2020-10-06 05:19:00.803667: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-06 05:19:02.166320: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-06 05:19:02.168649: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:19:02.169274: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-06 05:19:02.169312: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-06 05:19:02.170898: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-06 05:19:02.184342: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-06 05:19:02.184692: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-06 05:19:02.194680: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-06 05:19:02.195662: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-06 05:19:02.199636: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-06 05:19:02.199778: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:19:02.200371: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:19:02.200878: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-10-06 05:19:02.206492: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2200000000 Hz
# 2020-10-06 05:19:02.206758: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x324cbc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-06 05:19:02.206784: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-06 05:19:02.297701: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:19:02.298398: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x324cd80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-06 05:19:02.298435: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-10-06 05:19:02.298653: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:19:02.299281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-06 05:19:02.299325: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-06 05:19:02.299365: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-06 05:19:02.299389: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-06 05:19:02.299410: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-06 05:19:02.299436: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-06 05:19:02.299456: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-06 05:19:02.299477: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-06 05:19:02.299559: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:19:02.300163: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:19:02.300657: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-10-06 05:19:02.300703: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-06 05:19:02.909448: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-06 05:19:02.909509: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-10-06 05:19:02.909522: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-10-06 05:19:02.909739: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:19:02.910454: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:19:02.911045: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-06 05:19:02.911091: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14638 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# check variables match in each block
# blocks_0 and block1a match.
# blocks_1 and block2a match.
# blocks_2 and block2b match.
# blocks_3 and block3a match.
# blocks_4 and block3b match.
# blocks_5 and block4a match.
# blocks_6 and block4b match.
# blocks_7 and block4c match.
# blocks_8 and block5a match.
# blocks_9 and block5b match.
# blocks_10 and block5c match.
# blocks_11 and block6a match.
# blocks_12 and block6b match.
# blocks_13 and block6c match.
# blocks_14 and block6d match.
# blocks_15 and block7a match.
# skipping variable normalization/mean:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# skipping variable normalization/variance:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# skipping variable normalization/count:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# 309/312 weights updated

# %% [markdown]
# ## Training an EfficientNetB0 initialized with noisy student training weights

# %%
# Load the EfficientNetB0 model but exclude the classification layers
# Note that the model was trained using AdvProp (https://arxiv.org/abs/1911.09665)
base_model_eb0_ap = EfficientNetB0(weights="efficientnetb0_notop.h5", include_top=False)
base_model_eb0_ap.trainable = False # We are not fine-tuning at this point
get_training_model(base_model_eb0_ap).summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1280)              5120
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 6405
# =================================================================
# Total params: 4,061,096
# Trainable params: 8,965
# Non-trainable params: 4,052,131
# _________________________________________________________________

# %%
# CUSTOM LEARNING SCHEUDLE
# Reference: https://www.kaggle.com/cdeotte/how-to-compete-with-gpus-workshop
LR_START = 1e-5
LR_MAX = 1e-2
LR_RAMPUP_EPOCHS = 5
LR_SUSTAIN_EPOCHS = 0
LR_STEP_DECAY = 0.75

def lrfn(epoch):
    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        lr = LR_MAX * LR_STEP_DECAY**((epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS)//10)
    return lr
    
lr2 = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

rng = [i for i in range(100)]
y = [lrfn(x) for x in rng]
plt.plot(rng, y); 
plt.xlabel('epoch',size=14); plt.ylabel('learning rate',size=14)
plt.title('Training Schedule',size=16); plt.show()

# %%
# Train the model
model_eb0_ap = get_training_model(base_model_eb0_ap)
model_eb0_ap.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
start = time.time()
h = model_eb0_ap.fit(train_ds,
              validation_data=validation_ds,
              epochs=30,
              callbacks=[lr2])
print("Total training time (seconds): ",time.time()-start)
plot_progress(h)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/30
# 49/49 [==============================] - 6s 129ms/step - loss: 1.6320 - accuracy: 0.1885 - val_loss: 1.6675 - val_accuracy: 0.2036
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0020080000000000002.
# Epoch 2/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.4643 - accuracy: 0.3756 - val_loss: 1.6921 - val_accuracy: 0.2073
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.004006.
# Epoch 3/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3760 - accuracy: 0.4269 - val_loss: 1.7726 - val_accuracy: 0.1727
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.006004000000000001.
# Epoch 4/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3292 - accuracy: 0.4567 - val_loss: 1.6700 - val_accuracy: 0.2455
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008002.
# Epoch 5/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3278 - accuracy: 0.4708 - val_loss: 1.6942 - val_accuracy: 0.3455
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 6/30
# 49/49 [==============================] - 4s 87ms/step - loss: 1.3196 - accuracy: 0.4603 - val_loss: 1.8364 - val_accuracy: 0.2455
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 7/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3245 - accuracy: 0.4577 - val_loss: 1.5166 - val_accuracy: 0.2727
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 8/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3007 - accuracy: 0.4702 - val_loss: 1.6346 - val_accuracy: 0.2600
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 9/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3114 - accuracy: 0.4740 - val_loss: 1.4670 - val_accuracy: 0.3836
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 10/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2968 - accuracy: 0.4776 - val_loss: 1.4247 - val_accuracy: 0.3836
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 11/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2709 - accuracy: 0.5087 - val_loss: 1.3637 - val_accuracy: 0.4727
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 12/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2611 - accuracy: 0.4942 - val_loss: 1.3547 - val_accuracy: 0.4327
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 13/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2809 - accuracy: 0.4897 - val_loss: 1.3299 - val_accuracy: 0.4655
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 14/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2697 - accuracy: 0.4994 - val_loss: 1.2795 - val_accuracy: 0.4836
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 15/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2480 - accuracy: 0.5074 - val_loss: 1.2212 - val_accuracy: 0.5164
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 16/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2449 - accuracy: 0.5109 - val_loss: 1.2456 - val_accuracy: 0.4709
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 17/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2255 - accuracy: 0.5138 - val_loss: 1.2111 - val_accuracy: 0.5091
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 18/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2464 - accuracy: 0.5093 - val_loss: 1.1732 - val_accuracy: 0.5218
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 19/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2319 - accuracy: 0.5231 - val_loss: 1.1816 - val_accuracy: 0.5273
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 20/30
# 49/49 [==============================] - 4s 87ms/step - loss: 1.2150 - accuracy: 0.5208 - val_loss: 1.1780 - val_accuracy: 0.5164
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 21/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2339 - accuracy: 0.5058 - val_loss: 1.2004 - val_accuracy: 0.5036
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 22/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2244 - accuracy: 0.5061 - val_loss: 1.2017 - val_accuracy: 0.5091
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 23/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2190 - accuracy: 0.5115 - val_loss: 1.1996 - val_accuracy: 0.5182
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 24/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2277 - accuracy: 0.5202 - val_loss: 1.2094 - val_accuracy: 0.4964
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 25/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2134 - accuracy: 0.5163 - val_loss: 1.1619 - val_accuracy: 0.5218
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 26/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2046 - accuracy: 0.5349 - val_loss: 1.1644 - val_accuracy: 0.5309
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 27/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2166 - accuracy: 0.5231 - val_loss: 1.1603 - val_accuracy: 0.5327
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 28/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.1982 - accuracy: 0.5330 - val_loss: 1.1653 - val_accuracy: 0.5291
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 29/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.1945 - accuracy: 0.5292 - val_loss: 1.1528 - val_accuracy: 0.5291
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 30/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2097 - accuracy: 0.5234 - val_loss: 1.1559 - val_accuracy: 0.5509
# Total training time (seconds):  142.32411694526672

# %% [markdown]
# ## Training an EfficientNetB0 initialized with ImageNet weights

# %%
# Load the EfficientNetB0 model but exclude the classification layers
# This time the weights are from traditional ImageNet pre-training
base_model_eb0 = EfficientNetB0(weights="imagenet", include_top=False)
base_model_eb0.trainable = False # We are not fine-tuning at this point

# %%
# Train the model
model_eb0 = get_training_model(base_model_eb0)
model_eb0.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
start = time.time()
h = model_eb0.fit(train_ds,
              validation_data=validation_ds,
              epochs=30,
              callbacks=[lr2])
print("Total training time (seconds): ",time.time()-start)
plot_progress(h)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/30
# 49/49 [==============================] - 5s 110ms/step - loss: 1.6081 - accuracy: 0.2112 - val_loss: 1.6146 - val_accuracy: 0.1727
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0020080000000000002.
# Epoch 2/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.4462 - accuracy: 0.3917 - val_loss: 1.8739 - val_accuracy: 0.1945
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.004006.
# Epoch 3/30
# 49/49 [==============================] - 4s 87ms/step - loss: 1.3956 - accuracy: 0.4106 - val_loss: 1.9566 - val_accuracy: 0.1945
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.006004000000000001.
# Epoch 4/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3847 - accuracy: 0.4192 - val_loss: 1.7774 - val_accuracy: 0.2436
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008002.
# Epoch 5/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3688 - accuracy: 0.4304 - val_loss: 1.6269 - val_accuracy: 0.2436
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 6/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3614 - accuracy: 0.4420 - val_loss: 1.6195 - val_accuracy: 0.2436
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 7/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3397 - accuracy: 0.4356 - val_loss: 1.6626 - val_accuracy: 0.2491
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 8/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3237 - accuracy: 0.4571 - val_loss: 1.5915 - val_accuracy: 0.2436
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 9/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3169 - accuracy: 0.4593 - val_loss: 1.4851 - val_accuracy: 0.3055
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 10/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3059 - accuracy: 0.4670 - val_loss: 1.4466 - val_accuracy: 0.2909
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 11/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2957 - accuracy: 0.4785 - val_loss: 1.4080 - val_accuracy: 0.3309
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 12/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2916 - accuracy: 0.4766 - val_loss: 1.3643 - val_accuracy: 0.4418
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 13/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3287 - accuracy: 0.4487 - val_loss: 1.3114 - val_accuracy: 0.4673
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 14/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2799 - accuracy: 0.4715 - val_loss: 1.2807 - val_accuracy: 0.4582
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 15/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2685 - accuracy: 0.4766 - val_loss: 1.2614 - val_accuracy: 0.4655
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 16/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2653 - accuracy: 0.4843 - val_loss: 1.2458 - val_accuracy: 0.5200
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 17/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2841 - accuracy: 0.4728 - val_loss: 1.2873 - val_accuracy: 0.4655
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 18/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2729 - accuracy: 0.4776 - val_loss: 1.2733 - val_accuracy: 0.4564
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 19/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2630 - accuracy: 0.4904 - val_loss: 1.2497 - val_accuracy: 0.4836
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 20/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2554 - accuracy: 0.4913 - val_loss: 1.2185 - val_accuracy: 0.5182
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 21/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2466 - accuracy: 0.5006 - val_loss: 1.2536 - val_accuracy: 0.4800
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 22/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2528 - accuracy: 0.4792 - val_loss: 1.2412 - val_accuracy: 0.4909
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 23/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2600 - accuracy: 0.4917 - val_loss: 1.2317 - val_accuracy: 0.5109
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 24/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2619 - accuracy: 0.4885 - val_loss: 1.2239 - val_accuracy: 0.4836
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 25/30
# 49/49 [==============================] - 4s 87ms/step - loss: 1.2667 - accuracy: 0.4872 - val_loss: 1.2197 - val_accuracy: 0.4964
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 26/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2410 - accuracy: 0.5042 - val_loss: 1.2031 - val_accuracy: 0.5109
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 27/30
# 49/49 [==============================] - 4s 87ms/step - loss: 1.2549 - accuracy: 0.4955 - val_loss: 1.2089 - val_accuracy: 0.5273
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 28/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2620 - accuracy: 0.4872 - val_loss: 1.2373 - val_accuracy: 0.4709
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 29/30
# 49/49 [==============================] - 4s 88ms/step - loss: 1.2446 - accuracy: 0.4929 - val_loss: 1.2298 - val_accuracy: 0.5145
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 30/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2454 - accuracy: 0.4949 - val_loss: 1.2112 - val_accuracy: 0.5200
# Total training time (seconds):  135.27121925354004

# %% [markdown]
# ## Plotting sample predictions

# %%
# Utility to plot sample predictions 
def plot_predictions(images, labels, probability):
    plt.figure(figsize=(15, 15))
    for i, image in enumerate(images):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(image)
        predicted_label = CLASSES[np.argmax(probability[i])]
        maximum_probability = "{:.3f}".format(max(probability[i]))
        text = "{} with probability: {}".format(predicted_label, maximum_probability) + \
            "\nGround-truth: {}".format(CLASSES[int(labels[i])])
        plt.title(text)
        plt.axis("off")
    plt.show()

# %%
# Let's run inference on a batch of images from the validation set
(batch_images, batch_labels) = next(iter(validation_ds))
predictions = model_eb0.predict(batch_images)
plot_predictions(batch_images[:16], batch_labels[:16], predictions[:16])

# %%
# Let's run inference on a batch of images from the validation set
(batch_images, batch_labels) = next(iter(validation_ds))
predictions = model_eb0_ap.predict(batch_images)
plot_predictions(batch_images[:16], batch_labels[:16], predictions[:16])

# %% [markdown]
# ## Utilities for creating a targeted adversarial example

# %%
#@title
# Clipping utility so that the pixel values stay within [0,1]
EPS = 2./255

def clip_eps(delta_tensor):
    return tf.clip_by_value(delta_tensor, clip_value_min=-EPS, clip_value_max=EPS)

# %%
#@title
def generate_adversaries_targeted(model, image_tensor, delta, 
    true_index, target_index):
    # Loss and optimizer
    scc_loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    optimizer = tf.keras.optimizers.Adam(learning_rate=5e-3)

    for t in range(350):
        plt.show()
        with tf.GradientTape() as tape:
            tape.watch(delta)
            inp = (image_tensor + delta)/255.
            predictions = model(inp, training=False)
            loss = (- scc_loss(tf.convert_to_tensor([true_index]), predictions) + 
	                    scc_loss(tf.convert_to_tensor([target_index]), predictions))
            if t % 20 == 0:
                print(t, loss.numpy())
                # plt.imshow(50*delta.numpy().squeeze()+0.5)
            
        # Get the gradients
        gradients = tape.gradient(loss, delta)
        
        # Update the weights
        optimizer.apply_gradients([(gradients, delta)])

        # Clip so that the delta values are within [0,1]
        delta.assign_add(clip_eps(delta))

    return delta

# %%
#@title
def perturb_image(model, image, true, target):
    print("Before adversarial attack")
    preprocessed_image = image/255.
    probabilities = tf.nn.softmax(model.predict(preprocessed_image))
    class_index = np.argmax(probabilities)
    print("Ground-truth label: {} predicted label: {}".format(CLASSES[true], CLASSES[class_index]))
    
    # Initialize the perturbation quantity
    image_tensor = tf.constant(image, dtype=tf.float32)
    delta = tf.Variable(tf.zeros_like(image_tensor), trainable=True)

    # Get the adversary vector
    delta_tensor = generate_adversaries_targeted(model, image_tensor, delta, true, target)

    # See if the image changes
    plt.imshow((image_tensor + delta_tensor).numpy().squeeze()/255)
    plt.show()

    # Generate prediction
    perturbed_image = (image_tensor + delta_tensor)/255.
    print("After adversarial attack")
    
    # Generate predictions
    preds = model.predict(perturbed_image)[0]
    i = np.argmax(preds)
    pred_label = CLASSES[i]

    print("Predicted label: {}".format(pred_label))
    cv2.imwrite("perturbed_image.png", perturbed_image.numpy().squeeze())

# %% [markdown]
# Turning a dandelion (last image from the figure above) to a tulip.

# %%
# Pick an image from the validation set
index = 15
sample_val_image = (batch_images[index].numpy()*255).astype(np.uint8)
sample_val_image = np.expand_dims(sample_val_image, 0)

# %%
#@title EfficientNetB0 with ImageNet initialization
# Tulips class index 4
perturb_image(model_eb0, sample_val_image, batch_labels[index].numpy(), 4)
# Out:
# Before adversarial attack
# Ground-truth label: dandelion predicted label: dandelion
# 0 0.4548967
# 20 0.43438566
# 40 0.4114623
# 60 0.38780773
# 80 0.36387157
# 100 0.3397497
# 120 0.31562877
# 140 0.29171324
# 160 0.26811886
# 180 0.24490905
# 200 0.22232556
# 220 0.20039427
# 240 0.17924285
# 260 0.15892756
# 280 0.13951564
# 300 0.121114016
# 320 0.1035912
# 340 0.08711529
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# After adversarial attack
# Predicted label: roses

# %%
#@title EfficientNetB0 with AdvProp initialization
perturb_image(model_eb0_ap, sample_val_image, batch_labels[index].numpy(), 4)
# Out:
# Before adversarial attack
# Ground-truth label: dandelion predicted label: dandelion
# 0 0.088507175
# 20 0.06437838
# 40 0.037686467
# 60 0.010703206
# 80 -0.016297936
# 100 -0.043156266
# 120 -0.0698961
# 140 -0.096227646
# 160 -0.12228382
# 180 -0.14791667
# 200 -0.17317152
# 220 -0.19798136
# 240 -0.22227752
# 260 -0.24614644
# 280 -0.26952124
# 300 -0.29236102
# 320 -0.3146975
# 340 -0.33649504
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# After adversarial attack
# Predicted label: tulips
