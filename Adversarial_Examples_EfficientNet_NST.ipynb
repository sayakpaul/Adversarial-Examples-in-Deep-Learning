# %% [markdown]
# <a href="https://colab.research.google.com/github/sayakpaul/Adversarial-Examples-in-Deep-Learning/blob/master/Adversarial_Examples_EfficientNet_NST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Initial setup

# %%
# TensorFlow version
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.3.0

# %%
# Which GPU?
# !nvidia-smi
# Out:
# Tue Oct  6 05:30:40 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.23.05    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   35C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# Other imports
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import *
from tensorflow.keras.models import *

import tensorflow_datasets as tfds
tfds.disable_progress_bar()

import matplotlib.pyplot as plt
import numpy as np
import random
import shutil
import time
import cv2
import os

# Fix the seeds
SEED = 666
tf.random.set_seed(SEED)
np.random.seed(SEED)

# %% [markdown]
# ## Data collection

# %%
# Gather Flowers dataset
train_ds, validation_ds = tfds.load(
    "tf_flowers",
    split=["train[:85%]", "train[85%:]"],
    as_supervised=True
)

# Specify the class labels, we would need this to create targeted attacks
CLASSES = ["daisy", "dandelion", "roses", "sunflowers", "tulips"]
# Out:
# Downloading and preparing dataset tf_flowers/3.0.0 (download: 218.21 MiB, generated: Unknown size, total: 218.21 MiB) to /root/tensorflow_datasets/tf_flowers/3.0.0...
# WARNING:absl:Dataset tf_flowers is hosted on GCS. It will automatically be downloaded to your
# local data directory. If you'd instead prefer to read directly from our public
# GCS bucket (recommended if you're running on GCP), you can instead set
# data_dir=gs://tfds-data/datasets.
# Dataset tf_flowers downloaded and prepared to /root/tensorflow_datasets/tf_flowers/3.0.0. Subsequent calls will reuse this data.

# %%
# Visualization
plt.figure(figsize=(10, 10))
for i, (image, label) in enumerate(train_ds.take(9)):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(image)
    plt.title(CLASSES[int(label)])
    plt.axis("off")

# %% [markdown]
# ## Data preparation

# %%
# Image preprocessing utils

SIZE = (224, 224)

def preprocess_image(image, label):
    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, SIZE)
    return (image, label)

# %%
# Construct TensorFlow dataset
BATCH_SIZE = 64
AUTO = tf.data.experimental.AUTOTUNE

train_ds = (
    train_ds
    .map(preprocess_image, num_parallel_calls=AUTO)
    .cache()
    .shuffle(1024)
    .batch(BATCH_SIZE)
    .prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
)

validation_ds = (
    validation_ds
    .map(preprocess_image, num_parallel_calls=AUTO)
    .cache()
    .batch(BATCH_SIZE)
    .prefetch(buffer_size=tf.data.experimental.AUTOTUNE)
)

# %% [markdown]
# ## Model utilities

# %%
# Reference: https://keras.io/examples/vision/image_classification_efficientnet_fine_tuning/
def get_training_model(base_model):
    inputs = Input(shape=(224, 224, 3))
    x = base_model(inputs, training=False)
    x = GlobalAveragePooling2D()(x)
    x = BatchNormalization()(x)

    top_dropout_rate = 0.2
    x = Dropout(top_dropout_rate)(x)
    x = Dense(5, activation="softmax")(x)
    classifier = Model(inputs=inputs, outputs=x)
    
    return classifier

def plot_progress(hist):
    plt.plot(hist.history["loss"], label="train_loss")
    plt.plot(hist.history["val_loss"], label="validation_loss")
    plt.plot(hist.history["accuracy"], label="training_accuracy")
    plt.plot(hist.history["val_accuracy"], label="validation_accuracy")
    plt.title("Training Progress")
    plt.ylabel("accuracy/loss")
    plt.xlabel("epoch")
    plt.legend(loc="upper left")
    plt.show()

# %% [markdown]
# Fetch the noisy student training checkpoints for EfficientNetB0 and convert the checkpoints to `.h5`.

# %%
# !wget -q https://storage.googleapis.com/cloud-tpu-checkpoints/efficientnet/noisystudent/noisy_student_efficientnet-b0.tar.gz
# !tar -xf noisy_student_efficientnet-b0.tar.gz

# %%
# !wget -q https://raw.githubusercontent.com/yixingfu/tensorflow/updateweights/tensorflow/python/keras/applications/efficientnet_weight_update_util.py
# !python efficientnet_weight_update_util.py --model b0 --notop --ckpt \
       noisy_student_efficientnet-b0/model.ckpt --o efficientnetb0_notop.h5
# Out:
# 2020-10-06 05:30:59.230609: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-06 05:31:00.485186: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-10-06 05:31:00.487654: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:31:00.488196: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-06 05:31:00.488233: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-06 05:31:00.489683: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-06 05:31:00.500829: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-06 05:31:00.501149: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-06 05:31:00.505151: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-06 05:31:00.505983: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-06 05:31:00.509507: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-06 05:31:00.509619: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:31:00.510190: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:31:00.510661: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-10-06 05:31:00.510935: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN)to use the following CPU instructions in performance-critical operations:  AVX512F
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2020-10-06 05:31:00.516032: I tensorflow/core/platform/profile_utils/cpu_utils.cc:104] CPU Frequency: 2000179999 Hz
# 2020-10-06 05:31:00.516270: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x229ebc0 initialized for platform Host (this does not guarantee that XLA will be used). Devices:
# 2020-10-06 05:31:00.516297: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Host, Default Version
# 2020-10-06 05:31:00.600021: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:31:00.600666: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x229ed80 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2020-10-06 05:31:00.600702: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# 2020-10-06 05:31:00.600854: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:31:00.601403: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# 2020-10-06 05:31:00.601440: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-06 05:31:00.601466: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcublas.so.10
# 2020-10-06 05:31:00.601479: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcufft.so.10
# 2020-10-06 05:31:00.601492: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcurand.so.10
# 2020-10-06 05:31:00.601505: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusolver.so.10
# 2020-10-06 05:31:00.601517: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcusparse.so.10
# 2020-10-06 05:31:00.601529: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudnn.so.7
# 2020-10-06 05:31:00.601580: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:31:00.602088: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:31:00.602557: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1858] Adding visible gpu devices: 0
# 2020-10-06 05:31:00.602592: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2020-10-06 05:31:01.170528: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1257] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2020-10-06 05:31:01.170586: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1263]      0
# 2020-10-06 05:31:01.170596: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1276] 0:   N
# 2020-10-06 05:31:01.170759: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:31:01.171363: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-10-06 05:31:01.171852: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:39] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2020-10-06 05:31:01.171886: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1402] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14638 MB memory) -> physical GPU (device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0)
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16711680/16705208 [==============================] - 0s 0us/step
# check variables match in each block
# blocks_0 and block1a match.
# blocks_1 and block2a match.
# blocks_2 and block2b match.
# blocks_3 and block3a match.
# blocks_4 and block3b match.
# blocks_5 and block4a match.
# blocks_6 and block4b match.
# blocks_7 and block4c match.
# blocks_8 and block5a match.
# blocks_9 and block5b match.
# blocks_10 and block5c match.
# blocks_11 and block6a match.
# blocks_12 and block6b match.
# blocks_13 and block6c match.
# blocks_14 and block6d match.
# blocks_15 and block7a match.
# skipping variable normalization/mean:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# skipping variable normalization/variance:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# skipping variable normalization/count:0: normalization is a layerin keras implementation, but preprocessing in TF implementation.
# 309/312 weights updated

# %% [markdown]
# ## Training an EfficientNetB0 initialized with noisy student training weights

# %%
# Load the EfficientNetB0 model but exclude the classification layers
# Note that the model was trained using noisy student training (https://arxiv.org/abs/1911.04252)
base_model_eb0_nst = EfficientNetB0(weights="efficientnetb0_notop.h5", include_top=False)
base_model_eb0_nst.trainable = False # We are not fine-tuning at this point
get_training_model(base_model_eb0_nst).summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# efficientnetb0 (Functional)  (None, None, None, 1280)  4049571
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1280)              0
# _________________________________________________________________
# batch_normalization (BatchNo (None, 1280)              5120
# _________________________________________________________________
# dropout (Dropout)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 5)                 6405
# =================================================================
# Total params: 4,061,096
# Trainable params: 8,965
# Non-trainable params: 4,052,131
# _________________________________________________________________

# %%
# CUSTOM LEARNING SCHEUDLE
# Reference: https://www.kaggle.com/cdeotte/how-to-compete-with-gpus-workshop
LR_START = 1e-5
LR_MAX = 1e-2
LR_RAMPUP_EPOCHS = 5
LR_SUSTAIN_EPOCHS = 0
LR_STEP_DECAY = 0.75

def lrfn(epoch):
    if epoch < LR_RAMPUP_EPOCHS:
        lr = (LR_MAX - LR_START) / LR_RAMPUP_EPOCHS * epoch + LR_START
    elif epoch < LR_RAMPUP_EPOCHS + LR_SUSTAIN_EPOCHS:
        lr = LR_MAX
    else:
        lr = LR_MAX * LR_STEP_DECAY**((epoch - LR_RAMPUP_EPOCHS - LR_SUSTAIN_EPOCHS)//10)
    return lr
    
lr2 = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=True)

rng = [i for i in range(100)]
y = [lrfn(x) for x in rng]
plt.plot(rng, y); 
plt.xlabel('epoch',size=14); plt.ylabel('learning rate',size=14)
plt.title('Training Schedule',size=16); plt.show()

# %%
# Train the model
model_eb0_nst = get_training_model(base_model_eb0_nst)
model_eb0_nst.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
start = time.time()
h = model_eb0_nst.fit(train_ds,
              validation_data=validation_ds,
              epochs=30,
              callbacks=[lr2])
print("Total training time (seconds): ",time.time()-start)
plot_progress(h)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/30
# 49/49 [==============================] - 6s 122ms/step - loss: 1.6165 - accuracy: 0.1955 - val_loss: 1.6081 - val_accuracy: 0.1945
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0020080000000000002.
# Epoch 2/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.4935 - accuracy: 0.3571 - val_loss: 1.6117 - val_accuracy: 0.1855
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.004006.
# Epoch 3/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.4408 - accuracy: 0.3965 - val_loss: 1.6655 - val_accuracy: 0.1873
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.006004000000000001.
# Epoch 4/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3936 - accuracy: 0.4256 - val_loss: 1.8056 - val_accuracy: 0.1855
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008002.
# Epoch 5/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3760 - accuracy: 0.4343 - val_loss: 1.8559 - val_accuracy: 0.1855
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 6/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3604 - accuracy: 0.4538 - val_loss: 1.7475 - val_accuracy: 0.1855
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 7/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3523 - accuracy: 0.4471 - val_loss: 1.7340 - val_accuracy: 0.1855
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 8/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3332 - accuracy: 0.4500 - val_loss: 1.6051 - val_accuracy: 0.2436
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 9/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3368 - accuracy: 0.4519 - val_loss: 1.6765 - val_accuracy: 0.1873
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 10/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.3197 - accuracy: 0.4721 - val_loss: 1.4526 - val_accuracy: 0.3927
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 11/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2850 - accuracy: 0.4923 - val_loss: 1.3954 - val_accuracy: 0.4182
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 12/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2705 - accuracy: 0.4907 - val_loss: 1.3487 - val_accuracy: 0.4600
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 13/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2905 - accuracy: 0.4837 - val_loss: 1.4121 - val_accuracy: 0.3273
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 14/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2895 - accuracy: 0.4718 - val_loss: 1.3862 - val_accuracy: 0.4164
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 15/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2499 - accuracy: 0.5019 - val_loss: 1.2574 - val_accuracy: 0.4600
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 16/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.2455 - accuracy: 0.5115 - val_loss: 1.2862 - val_accuracy: 0.4673
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 17/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2422 - accuracy: 0.5083 - val_loss: 1.2369 - val_accuracy: 0.4745
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 18/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2581 - accuracy: 0.5042 - val_loss: 1.2670 - val_accuracy: 0.4691
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 19/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2530 - accuracy: 0.5058 - val_loss: 1.2050 - val_accuracy: 0.5127
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 20/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2333 - accuracy: 0.5054 - val_loss: 1.2020 - val_accuracy: 0.5055
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 21/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2356 - accuracy: 0.5071 - val_loss: 1.2515 - val_accuracy: 0.4727
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 22/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2228 - accuracy: 0.5205 - val_loss: 1.1875 - val_accuracy: 0.5255
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 23/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2223 - accuracy: 0.5199 - val_loss: 1.2485 - val_accuracy: 0.5000
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 24/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2330 - accuracy: 0.5058 - val_loss: 1.2304 - val_accuracy: 0.4927
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 25/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2185 - accuracy: 0.5199 - val_loss: 1.1876 - val_accuracy: 0.5109
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 26/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2034 - accuracy: 0.5282 - val_loss: 1.1901 - val_accuracy: 0.5182
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 27/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2198 - accuracy: 0.5119 - val_loss: 1.1890 - val_accuracy: 0.5291
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 28/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.1965 - accuracy: 0.5250 - val_loss: 1.1741 - val_accuracy: 0.5345
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 29/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.1950 - accuracy: 0.5308 - val_loss: 1.1635 - val_accuracy: 0.5382
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 30/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2098 - accuracy: 0.5199 - val_loss: 1.1723 - val_accuracy: 0.5182
# Total training time (seconds):  140.60777020454407

# %% [markdown]
# ## Training an EfficientNetB0 initialized with ImageNet weights

# %%
# Load the EfficientNetB0 model but exclude the classification layers
# This time the weights are from traditional ImageNet pre-training
base_model_eb0 = EfficientNetB0(weights="imagenet", include_top=False)
base_model_eb0.trainable = False # We are not fine-tuning at this point

# %%
# Train the model
model_eb0 = get_training_model(base_model_eb0)
model_eb0.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=["accuracy"])
start = time.time()
h = model_eb0.fit(train_ds,
              validation_data=validation_ds,
              epochs=30,
              callbacks=[lr2])
print("Total training time (seconds): ",time.time()-start)
plot_progress(h)
# Out:
# Epoch 00001: LearningRateScheduler reducing learning rate to 1e-05.
# Epoch 1/30
# 49/49 [==============================] - 5s 110ms/step - loss: 1.6081 - accuracy: 0.2112 - val_loss: 1.6146 - val_accuracy: 0.1727
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0020080000000000002.
# Epoch 2/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.4462 - accuracy: 0.3917 - val_loss: 1.8739 - val_accuracy: 0.1945
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.004006.
# Epoch 3/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3956 - accuracy: 0.4106 - val_loss: 1.9566 - val_accuracy: 0.1945
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.006004000000000001.
# Epoch 4/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3847 - accuracy: 0.4192 - val_loss: 1.7774 - val_accuracy: 0.2436
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.008002.
# Epoch 5/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.3688 - accuracy: 0.4304 - val_loss: 1.6269 - val_accuracy: 0.2436
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 6/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3614 - accuracy: 0.4420 - val_loss: 1.6195 - val_accuracy: 0.2436
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 7/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.3397 - accuracy: 0.4356 - val_loss: 1.6626 - val_accuracy: 0.2491
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 8/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.3237 - accuracy: 0.4571 - val_loss: 1.5915 - val_accuracy: 0.2436
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 9/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.3169 - accuracy: 0.4593 - val_loss: 1.4851 - val_accuracy: 0.3055
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 10/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3059 - accuracy: 0.4670 - val_loss: 1.4466 - val_accuracy: 0.2909
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 11/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2957 - accuracy: 0.4785 - val_loss: 1.4080 - val_accuracy: 0.3309
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 12/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2916 - accuracy: 0.4766 - val_loss: 1.3643 - val_accuracy: 0.4418
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 13/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.3287 - accuracy: 0.4487 - val_loss: 1.3114 - val_accuracy: 0.4673
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 14/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.2799 - accuracy: 0.4715 - val_loss: 1.2807 - val_accuracy: 0.4582
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.01.
# Epoch 15/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.2685 - accuracy: 0.4766 - val_loss: 1.2614 - val_accuracy: 0.4655
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 16/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2653 - accuracy: 0.4843 - val_loss: 1.2458 - val_accuracy: 0.5200
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 17/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2841 - accuracy: 0.4728 - val_loss: 1.2873 - val_accuracy: 0.4655
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 18/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2729 - accuracy: 0.4776 - val_loss: 1.2733 - val_accuracy: 0.4564
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 19/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2630 - accuracy: 0.4904 - val_loss: 1.2497 - val_accuracy: 0.4836
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 20/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2554 - accuracy: 0.4913 - val_loss: 1.2185 - val_accuracy: 0.5182
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 21/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2466 - accuracy: 0.5006 - val_loss: 1.2536 - val_accuracy: 0.4800
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 22/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.2528 - accuracy: 0.4792 - val_loss: 1.2412 - val_accuracy: 0.4909
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 23/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.2600 - accuracy: 0.4917 - val_loss: 1.2317 - val_accuracy: 0.5109
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 24/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2619 - accuracy: 0.4885 - val_loss: 1.2239 - val_accuracy: 0.4836
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0075.
# Epoch 25/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2667 - accuracy: 0.4872 - val_loss: 1.2197 - val_accuracy: 0.4964
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 26/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2410 - accuracy: 0.5042 - val_loss: 1.2031 - val_accuracy: 0.5109
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 27/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.2549 - accuracy: 0.4955 - val_loss: 1.2089 - val_accuracy: 0.5273
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 28/30
# 49/49 [==============================] - 4s 84ms/step - loss: 1.2620 - accuracy: 0.4872 - val_loss: 1.2373 - val_accuracy: 0.4709
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 29/30
# 49/49 [==============================] - 4s 86ms/step - loss: 1.2446 - accuracy: 0.4929 - val_loss: 1.2298 - val_accuracy: 0.5145
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.005625.
# Epoch 30/30
# 49/49 [==============================] - 4s 85ms/step - loss: 1.2454 - accuracy: 0.4949 - val_loss: 1.2112 - val_accuracy: 0.5200
# Total training time (seconds):  133.19893860816956

# %% [markdown]
# ## Plotting sample predictions

# %%
# Utility to plot sample predictions 
def plot_predictions(images, labels, probability):
    plt.figure(figsize=(15, 15))
    for i, image in enumerate(images):
        ax = plt.subplot(4, 4, i + 1)
        plt.imshow(image)
        predicted_label = CLASSES[np.argmax(probability[i])]
        maximum_probability = "{:.3f}".format(max(probability[i]))
        text = "{} with probability: {}".format(predicted_label, maximum_probability) + \
            "\nGround-truth: {}".format(CLASSES[int(labels[i])])
        plt.title(text)
        plt.axis("off")
    plt.show()

# %%
# Let's run inference on a batch of images from the validation set
(batch_images, batch_labels) = next(iter(validation_ds))
predictions = model_eb0.predict(batch_images)
plot_predictions(batch_images[:16], batch_labels[:16], predictions[:16])

# %%
# Let's run inference on a batch of images from the validation set
(batch_images, batch_labels) = next(iter(validation_ds))
predictions = model_eb0_nst.predict(batch_images)
plot_predictions(batch_images[:16], batch_labels[:16], predictions[:16])

# %% [markdown]
# ## Utilities for creating a targeted adversarial example

# %%
#@title
# Clipping utility so that the pixel values stay within [0,1]
EPS = 2./255

def clip_eps(delta_tensor):
    return tf.clip_by_value(delta_tensor, clip_value_min=-EPS, clip_value_max=EPS)

# %%
#@title
def generate_adversaries_targeted(model, image_tensor, delta, 
    true_index, target_index):
    # Loss and optimizer
    scc_loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True)
    optimizer = tf.keras.optimizers.Adam(learning_rate=5e-3)

    for t in range(350):
        plt.show()
        with tf.GradientTape() as tape:
            tape.watch(delta)
            inp = (image_tensor + delta)/255.
            predictions = model(inp, training=False)
            loss = (- scc_loss(tf.convert_to_tensor([true_index]), predictions) + 
	                    scc_loss(tf.convert_to_tensor([target_index]), predictions))
            if t % 20 == 0:
                print(t, loss.numpy())
                # plt.imshow(50*delta.numpy().squeeze()+0.5)
            
        # Get the gradients
        gradients = tape.gradient(loss, delta)
        
        # Update the weights
        optimizer.apply_gradients([(gradients, delta)])

        # Clip so that the delta values are within [0,1]
        delta.assign_add(clip_eps(delta))

    return delta

# %%
#@title
def perturb_image(model, image, true, target):
    print("Before adversarial attack")
    preprocessed_image = image/255.
    probabilities = tf.nn.softmax(model.predict(preprocessed_image))
    class_index = np.argmax(probabilities)
    print("Ground-truth label: {} predicted label: {}".format(CLASSES[true], CLASSES[class_index]))
    
    # Initialize the perturbation quantity
    image_tensor = tf.constant(image, dtype=tf.float32)
    delta = tf.Variable(tf.zeros_like(image_tensor), trainable=True)

    # Get the adversary vector
    delta_tensor = generate_adversaries_targeted(model, image_tensor, delta, true, target)

    # See if the image changes
    plt.imshow((image_tensor + delta_tensor).numpy().squeeze()/255)
    plt.show()

    # Generate prediction
    perturbed_image = (image_tensor + delta_tensor)/255.
    print("After adversarial attack")
    
    # Generate predictions
    preds = model.predict(perturbed_image)[0]
    i = np.argmax(preds)
    pred_label = CLASSES[i]

    print("Predicted label: {}".format(pred_label))
    cv2.imwrite("perturbed_image.png", perturbed_image.numpy().squeeze())

# %% [markdown]
# Turning a dandelion (last image from the figure above) to a tulip.

# %%
# Pick an image from the validation set
index = 15
sample_val_image = (batch_images[index].numpy()*255).astype(np.uint8)
sample_val_image = np.expand_dims(sample_val_image, 0)

# %%
#@title EfficientNetB0 with ImageNet initialization
# Tulips class index 4
perturb_image(model_eb0, sample_val_image, batch_labels[index].numpy(), 4)
# Out:
# Before adversarial attack
# Ground-truth label: dandelion predicted label: dandelion
# 0 0.45489717
# 20 0.43438017
# 40 0.4114449
# 60 0.3878337
# 80 0.36386907
# 100 0.33977473
# 120 0.3156196
# 140 0.2917137
# 160 0.2680924
# 180 0.24492145
# 200 0.22234249
# 220 0.20039654
# 240 0.17922163
# 260 0.15894079
# 280 0.13953114
# 300 0.121080756
# 320 0.10363054
# 340 0.08709133
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# After adversarial attack
# Predicted label: roses

# %%
#@title EfficientNetB0 with noisy student training initialization
perturb_image(model_eb0_nst, sample_val_image, batch_labels[index].numpy(), 4)
# Out:
# Before adversarial attack
# Ground-truth label: dandelion predicted label: roses
# 0 0.08339453
# 20 0.06359136
# 40 0.042381883
# 60 0.02159357
# 80 0.0017147064
# 100 -0.017243743
# 120 -0.035338998
# 140 -0.05234027
# 160 -0.06848037
# 180 -0.083661795
# 200 -0.09793854
# 220 -0.111418486
# 240 -0.12416446
# 260 -0.13624203
# 280 -0.14760411
# 300 -0.15850997
# 320 -0.16892481
# 340 -0.17898297
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# After adversarial attack
# Predicted label: roses
